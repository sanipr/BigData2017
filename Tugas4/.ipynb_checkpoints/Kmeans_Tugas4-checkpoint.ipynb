# %%
# Konfigurasi Spark
import os
import sys
from pprint import pprint
from matplotlib import pyplot

# 1. Lokasi di mana Spark diinstal
spark_path = "/Users/sani/Kuliah/Sem8/BigData/spark-2.1.0-bin-hadoop2.7"

# 2. Menentukan environment variable
os.environ['SPARK_HOME'] = spark_path


# 3. Download winutils dari https://github.com/steveloughran/winutils/blob/master/hadoop-2.6.0/bin/winutils.exe?raw=true
#   dan letakkan di dalam folder D:\spark\bin\
#   Lokasi winutils.exe
os.environ['HADOOP_HOME'] = spark_path

# 4. Lokasi Python yang dijalankan --> punya Anaconda
#    Apabila Python yang diinstall hanya Anaconda, maka tidak perlu menjalankan baris ini.
os.environ['PYSPARK_PYTHON'] = sys.executable

# 5. Konfigurasi path library PySpark
sys.path.append(spark_path + "/bin")
sys.path.append(spark_path + "/python")
sys.path.append(spark_path + "/python/pyspark/")
sys.path.append(spark_path + "/python/lib")
sys.path.append(spark_path + "/python/lib/pyspark.zip")
sys.path.append(spark_path + "/python/lib/py4j-0.10.4-src.zip")

#############################################################

from __future__ import print_function

# $example on$
from numpy import array
from math import sqrt
# $example off$

from pyspark import SparkContext
# $example on$
from pyspark.mllib.clustering import KMeans, KMeansModel
# $example off$

if __name__ == "__main__":
    sc = SparkContext(appName="KMeansExample")  # SparkContext

    # $example on$
    # Load and parse the data
    data = sc.textFile("/Users/sani/Kuliah/Sem8/BigData/BigData2017/Tugas4/complete.csv")
#     parsedData = data.map(lambda line: array([float(x) for x in line.split(' ')]))

# %%
#remove header and split data
header=data.first()
wohead=data.filter(lambda line:line != header)
wohead.first()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-95-d900956ac2e4> in <module>()
#       2 header=data.first()
#       3 wohead=data.filter(lambda line:line != header).map(lambda line: array([float(x) for x in line.split(",")]))
# ----> 4 wohead.first()
#
# /Users/sani/Kuliah/Sem8/BigData/spark-2.1.0-bin-hadoop2.7/python/pyspark/rdd.pyc in first(self)
#    1359         ValueError: RDD is empty
#    1360         """
# -> 1361         rs = self.take(1)
#    1362         if rs:
#    1363             return rs[0]
#
# /Users/sani/Kuliah/Sem8/BigData/spark-2.1.0-bin-hadoop2.7/python/pyspark/rdd.pyc in take(self, num)
#    1341
#    1342             p = range(partsScanned, min(partsScanned + numPartsToTry, totalParts))
# -> 1343             res = self.context.runJob(self, takeUpToNumLeft, p)
#    1344
#    1345             items += res
#
# ...

# %%
#select lattitude and longitude column
latlong=wohead.map(lambda x: (x[9],x[10]))
latlong.take(5)
# Out:
# [(u'29.8830556', u'-97.9411111'),
#  (u'29.38421', u'-98.581082'),
#  (u'53.2', u'-2.916667'),
#  (u'28.9783333', u'-96.6458333'),
#  (u'21.4180556', u'-157.8036111')]

# %%
hoho=latlong

# %%
from collections import namedtuple
fields = ('lat','long')
complete = namedtuple('complete',fields, verbose=True)
def parse(row):
    row[0] = float(row[0])
    row[1] = float(row[1])
    return complete(*row[:2])
# Out:
# class complete(tuple):
#     'complete(lat, long)'
#
#     __slots__ = ()
#
#     _fields = ('lat', 'long')
#
#     def __new__(_cls, lat, long):
#         'Create new instance of complete(lat, long)'
#         return _tuple.__new__(_cls, (lat, long))
#
#     @classmethod
#     def _make(cls, iterable, new=tuple.__new__, len=len):
#         'Make a new complete object from a sequence or iterable'
#         result = new(cls, iterable)
#         if len(result) != 2:
#             raise TypeError('Expected 2 arguments, got %d' % len(result))
#         return result
#
#     def __repr__(self):
#         'Return a nicely formatted representation string'
#         return 'complete(lat=%r, long=%r)' % self
#
#     def _asdict(self):
#         'Return a new OrderedDict which maps field names to their values'
#         return OrderedDict(zip(self._fields, self))
#
#     def _replace(_self, **kwds):
#         'Return a new complete object replacing specified fields with new values'
# ...

# %%
# from numpy import array
# completeParsed=latlong.map(lambda line: array([float(x) for x in line]))
completeParsed=latlong.map(parse)

# %%
latlong.first()
# Out:
# (u'29.8830556', u'-97.9411111')

# %%
completeParsed.collect()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-21-7d560ff54780> in <module>()
# ----> 1 completeParsed.collect()
#
# /Users/sani/Kuliah/Sem8/BigData/spark-2.1.0-bin-hadoop2.7/python/pyspark/rdd.pyc in collect(self)
#     807         """
#     808         with SCCallSiteSync(self.context) as css:
# --> 809             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     810         return list(_load_from_socket(port, self._jrdd_deserializer))
#     811
#
# /Users/sani/Kuliah/Sem8/BigData/spark-2.1.0-bin-hadoop2.7/python/lib/py4j-0.10.4-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1131         answer = self.gateway_client.send_command(command)
#    1132         return_value = get_return_value(
# -> 1133             answer, self.gateway_client, self.target_id, self.name)
#    1134
#    1135         for temp_arg in temp_args:
#
# ...

# %%
clean=completeParsed.map(lambda x:x.lat!=0)
clean.count()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-17-68fd1e5aa578> in <module>()
#       1 clean=completeParsed.map(lambda x:x.lat!=0)
# ----> 2 clean.count()
#
# /Users/sani/Kuliah/Sem8/BigData/spark-2.1.0-bin-hadoop2.7/python/pyspark/rdd.pyc in count(self)
#    1039         3
#    1040         """
# -> 1041         return self.mapPartitions(lambda i: [sum(1 for _ in i)]).sum()
#    1042
#    1043     def stats(self):
#
# /Users/sani/Kuliah/Sem8/BigData/spark-2.1.0-bin-hadoop2.7/python/pyspark/rdd.pyc in sum(self)
#    1030         6.0
#    1031         """
# -> 1032         return self.mapPartitions(lambda x: [sum(x)]).fold(0, operator.add)
#    1033
#    1034     def count(self):
#
# /Users/sani/Kuliah/Sem8/BigData/spark-2.1.0-bin-hadoop2.7/python/pyspark/rdd.pyc in fold(self, zeroValue, op)
# ...

# %%
cleaned=clean.map(lambda x:x.long!=0)

# %%
clean=completeParsed.map(lambda x:x.lat).reduce(lambda x,y:x+y)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-16-d56ed1793b4b> in <module>()
# ----> 1 clean=completeParsed.map(lambda x:x.lat).reduce(lambda x,y:x+y)
#
# /Users/sani/Kuliah/Sem8/BigData/spark-2.1.0-bin-hadoop2.7/python/pyspark/rdd.pyc in reduce(self, f)
#     833             yield reduce(f, iterator, initial)
#     834
# --> 835         vals = self.mapPartitions(func).collect()
#     836         if vals:
#     837             return reduce(f, vals)
#
# /Users/sani/Kuliah/Sem8/BigData/spark-2.1.0-bin-hadoop2.7/python/pyspark/rdd.pyc in collect(self)
#     807         """
#     808         with SCCallSiteSync(self.context) as css:
# --> 809             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     810         return list(_load_from_socket(port, self._jrdd_deserializer))
#     811
#
# ...

# %%
    # Build the model (cluster the data)
    clusters = KMeans.train(parsedData, 2, maxIterations=10, initializationMode="random")
    
    #plot variance for each value for 'k' between 1,10
    initial = [clusters.vq.kmeans(parsedData,i) for i in range(1,10)]
    pyplot.plot([var for (cent,var) in initial])
    pyplot.show()
    
    # Evaluate clustering by computing Within Set Sum of Squared Errors
    def error(point):
        center = clusters.centers[clusters.predict(point)]
        return sqrt(sum([x**2 for x in (point - center)]))

    WSSSE = parsedData.map(lambda point: error(point)).reduce(lambda x, y: x + y)
    print("Within Set Sum of Squared Error = " + str(WSSSE))

    # Save and load model
    clusters.save(sc, "target/org/apache/spark/PythonKMeansExample/KMeansModel")
    sameModel = KMeansModel.load(sc, "target/org/apache/spark/PythonKMeansExample/KMeansModel")
    # $example off$

    sc.stop()
