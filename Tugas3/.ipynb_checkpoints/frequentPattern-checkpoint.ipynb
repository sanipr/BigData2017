# %%
# Konfigurasi Spark
import os
import sys

# 1. Lokasi di mana Spark diinstal
spark_path = "/Users/sani/Kuliah/Sem8/BigData/spark-2.1.0-bin-hadoop2.7"

# 2. Menentukan environment variable
os.environ['SPARK_HOME'] = spark_path


# 3. Download winutils dari https://github.com/steveloughran/winutils/blob/master/hadoop-2.6.0/bin/winutils.exe?raw=true
#   dan letakkan di dalam folder D:\spark\bin\
#   Lokasi winutils.exe
os.environ['HADOOP_HOME'] = spark_path

# 4. Lokasi Python yang dijalankan --> punya Anaconda
#    Apabila Python yang diinstall hanya Anaconda, maka tidak perlu menjalankan baris ini.
os.environ['PYSPARK_PYTHON'] = sys.executable

# 5. Konfigurasi path library PySpark
sys.path.append(spark_path + "/bin")
sys.path.append(spark_path + "/python")
sys.path.append(spark_path + "/python/pyspark/")
sys.path.append(spark_path + "/python/lib")
sys.path.append(spark_path + "/python/lib/pyspark.zip")
sys.path.append(spark_path + "/python/lib/py4j-0.10.4-src.zip")

from pyspark import SparkContext
from pyspark import SparkConf

sc = SparkContext("local", "test")

print sc

# %%
from pyspark.mllib.fpm import FPGrowth

data = sc.textFile("/Users/sani/Kuliah/Sem8/BigData/spark-2.1.0-bin-hadoop2.7/data/mllib/sample_fpgrowth.txt")
transactions = data.map(lambda line: line.strip().split(' '))
model = FPGrowth.train(transactions, minSupport=0.1, numPartitions=10)
result = model.freqItemsets().collect()
for fi in result:
    print(fi)
# Out:
# FreqItemset(items=[u'o'], freq=1)
# FreqItemset(items=[u'o', u'n'], freq=1)
# FreqItemset(items=[u'o', u'n', u's'], freq=1)
# FreqItemset(items=[u'o', u'n', u's', u'x'], freq=1)
# FreqItemset(items=[u'o', u'n', u's', u'r'], freq=1)
# FreqItemset(items=[u'o', u'n', u's', u'r', u'x'], freq=1)
# FreqItemset(items=[u'o', u'n', u'x'], freq=1)
# FreqItemset(items=[u'o', u'n', u'r'], freq=1)
# FreqItemset(items=[u'o', u'n', u'r', u'x'], freq=1)
# FreqItemset(items=[u'o', u's'], freq=1)
# FreqItemset(items=[u'o', u's', u'x'], freq=1)
# FreqItemset(items=[u'o', u's', u'r'], freq=1)
# FreqItemset(items=[u'o', u's', u'r', u'x'], freq=1)
# FreqItemset(items=[u'o', u'x'], freq=1)
# FreqItemset(items=[u'o', u'r'], freq=1)
# FreqItemset(items=[u'o', u'r', u'x'], freq=1)
# FreqItemset(items=[u'z'], freq=5)
# FreqItemset(items=[u'h'], freq=1)
# FreqItemset(items=[u'h', u'r'], freq=1)
# FreqItemset(items=[u'h', u'r', u'z'], freq=1)
# FreqItemset(items=[u'h', u'p'], freq=1)
# ...

# %%
from pyspark.mllib.fpm import FPGrowth

data = sc.textFile("/Users/sani/Kuliah/Sem8/BigData/BigData2017/Tugas3/pakaian.txt")
transactions = data.map(lambda line: line.strip().split(' '))
model = FPGrowth.train(transactions, minSupport=0.1, numPartitions=10)
result = model.freqItemsets().collect()
for fi in result:
    print(fi)
# Out:
# FreqItemset(items=[u'bajuputih'], freq=7)
# FreqItemset(items=[u'sepatucoklat'], freq=6)
# FreqItemset(items=[u'rokhitam'], freq=6)
# FreqItemset(items=[u'celanahitam'], freq=5)
# FreqItemset(items=[u'jilbabcoklat'], freq=5)
# FreqItemset(items=[u'jilbabcoklat', u'rokhitam'], freq=3)
# FreqItemset(items=[u'jilbabcoklat', u'sepatucoklat'], freq=3)
# FreqItemset(items=[u'jilbabcoklat', u'bajuputih'], freq=3)
# FreqItemset(items=[u'jilbabmerah'], freq=3)
# FreqItemset(items=[u'sepatuputih'], freq=3)
# FreqItemset(items=[u'sepatuputih', u'bajuputih'], freq=3)
# FreqItemset(items=[u'jilbabhitam'], freq=3)
# FreqItemset(items=[u'bajuhitam'], freq=3)

# %%
#mengggunakan data 2 yang diperbanyak jumlahnya
from pyspark.mllib.fpm import FPGrowth

data2 = sc.textFile("/Users/sani/Kuliah/Sem8/BigData/BigData2017/Tugas3/pakaian2.txt")
transactions2 = data2.map(lambda line: line.strip().split(' '))
model = FPGrowth.train(transactions2, minSupport=0.3, numPartitions=10)
result = model.freqItemsets().collect()
for fi in result:
    print(fi)
# Out:
# FreqItemset(items=[u'rokhitam'], freq=576)
# FreqItemset(items=[u'bajuputih'], freq=544)
